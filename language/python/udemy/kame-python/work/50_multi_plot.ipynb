# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(-10, 10, 100)

# %%
plt.plot(x, x**2)

# %%
plt.plot(x, x**3)

# %%
plt.subplot(1, 2, 1)
plt.plot(x, x**2)
plt.subplot(1, 2, 2)
plt.plot(x, x**3)

# %%
plt.subplot(1, 2, 1)
plt.plot(x, x**2)
plt.subplot(2, 2, 2)
plt.plot(x, x**3)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1, 2, 1)

ax1.plot(x, x**2)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

ax1.plot(x, x**2)
ax2.plot(x, x**3)

# %%
fix, axes = plt.subplots(1, 2)
axes[0].plot(x, x**2)
axes[1].plot(x, x**3)

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f89c8cc7f50>,
# ...
#       dtype=object)

# %%
fig, axes = plt.subplots(2, 2)

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f89c7755350>,
# ...
#       dtype=object)

# %%
type(axes)
# Out:
# numpy.ndarray

# %%
fig, axes = plt.subplots(2, 2)
axes[0][0].plot(x, x**2)

# %%
fig, axes = plt.subplots(2, 2)
axes[0, 0].plot(x, x**2, color='r')
axes[0, 1].plot(x, x**3)
axes[1, 0].plot(x, x**4)
axes[1, 1].plot(x, x**5)

# %%
fig, axes = plt.subplots(2, 2)
axes[0, 0].plot(x, x**2, color='r')
axes[0, 1].plot(x, x**3)
axes[1, 0].plot(x, x**4)
axes[1, 1].plot(x, x**5)
fig.tight_layout()

# %%
fig, axes = plt.subplots()
axes.plot(x, x**2)

# %%
axes

# %%
fig, axes = plt.subplots(1, 2)
axes[0].plot(x, x**2, color='r',label='x**2')
axes[1].plot(x, x**3)
axes[0].set_xlabel('xlabell')
axes[0].set_ylabel('ylabell')
axes[1].set_title('x**3')
axes[0].set_xticks([-3,-2,-1,3])
axes[0].set_yticks([0,10,20])

axes[0].legend()
axes[1].axis('off')
fig.tight_layout()
