# %%
import pandas as pd

# %%
df = pd.read_csv('tmdb_5000_movies.csv')

# %%
df.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
# ...

# %%
df.groupby('original_language')

# %%
df.groupby('original_language').mean()
# Out:
#                          budget             id  popularity       revenue  \
# original_language
# af                 3.000000e+06     868.000000    2.504169  9.879971e+06
# ar                 0.000000e+00   83505.000000    4.723389  0.000000e+00
# cn                 1.072641e+07  109470.500000   10.631343  3.374016e+07
# cs                 0.000000e+00  185196.000000    1.286848  0.000000e+00
# da                 9.742857e+06   33440.714286   17.663925  2.989889e+07
# de                 8.616354e+06   63369.518519   10.151382  1.396191e+07
# el                 0.000000e+00   38810.000000   28.858238  1.101970e+05
# en                 3.039436e+07   55788.758047   22.177435  8.647885e+07
# es                 5.847683e+06   73720.937500   13.330804  1.865218e+07
# fa                 2.450000e+05   38974.000000    5.664415  2.250000e+05
# fr                 8.480997e+06   62312.171429   10.299542  1.246151e+07
# he                 6.666667e+05   16428.333333    5.364953  3.708616e+06
# ...

# %%
df.groupby('original_language').mean().loc['ja']
# Out:
# budget          1.429361e+07
# id              5.389425e+04
# popularity      2.566379e+01
# revenue         6.602892e+07
# runtime         1.225000e+02
# vote_average    7.050000e+00
# vote_count      7.157500e+02
# Name: ja, dtype: float64

# %%
df[df['original_language']== 'ja' ]
# Out:
#         budget                                             genres  \
# 97    15000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1471  41677699  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 1709  30000000  [{"id": 16, "name": "Animation"}, {"id": 878, ...
# 1987  24000000  [{"id": 14, "name": "Fantasy"}, {"id": 16, "na...
# 2247  26500000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2258  20000000  [{"id": 16, "name": "Animation"}, {"id": 14, "...
# 2294  15000000  [{"id": 14, "name": "Fantasy"}, {"id": 12, "na...
# 2888  12000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 2900  12000000           [{"id": 878, "name": "Science Fiction"}]
# 2908         0                      [{"id": 18, "name": "Drama"}]
# 3296   8000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 3542   5500000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3901  16000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
df[df['original_language']== 'ja' ]['budget'].mean()
# Out:
# 14293606.1875

# %%
df.groupby('original_language').mean().loc['ja']
# Out:
# budget          1.429361e+07
# id              5.389425e+04
# popularity      2.566379e+01
# revenue         6.602892e+07
# runtime         1.225000e+02
# vote_average    7.050000e+00
# vote_count      7.157500e+02
# Name: ja, dtype: float64

# %%
df.groupby('original_language').mean().loc['ja']['budget']
# Out:
# 14293606.1875

# %%
df[~(df['budget'] == 0)].groupby('original_language').mean().loc['ja']['budget']
# Out:
# 15246513.266666668

# %%
df[(df['budget'] != 0) & (df['original_language'] == 'ja' )].mean()['budget']
# Out:
# 15246513.266666668

# %%
df[df['budget'] == 0].groupby('original_language').count()['budget']
# Out:
# original_language
# ar      2
# cn      5
# cs      2
# da      1
# de     11
# el      1
# en    921
# es      8
# fa      2
# fr     31
# he      2
# hi     10
# hu      1
# it      6
# ja      1
# ko      4
# ky      1
# nl      1
# pt      6
# ro      1
# ru      3
# sl      1
# sv      4
# ta      2
# th      1
# zh      9
# Name: budget, dtype: int64

# %%
df.groupby('original_language').describe()
# Out:
#                    budget                                                      \
#                     count          mean           std         min         25%
# original_language
# af                    1.0  3.000000e+06           NaN   3000000.0   3000000.0
# ar                    2.0  0.000000e+00  0.000000e+00         0.0         0.0
# cn                   12.0  1.072641e+07  1.245921e+07         0.0         0.0
# cs                    2.0  0.000000e+00  0.000000e+00         0.0         0.0
# da                    7.0  9.742857e+06  1.207834e+07         0.0   2550000.0
# de                   27.0  8.616354e+06  1.910675e+07         0.0         0.0
# el                    1.0  0.000000e+00           NaN         0.0         0.0
# en                 4505.0  3.039436e+07  4.150614e+07         0.0   1000000.0
# es                   32.0  5.847683e+06  8.443275e+06         0.0    165000.0
# fa                    4.0  2.450000e+05  3.796051e+05         0.0         0.0
# ...

# %%
df.groupby('original_language').describe().columns
# Out:
# MultiIndex([(      'budget', 'count'),
#             (      'budget',  'mean'),
#             (      'budget',   'std'),
#             (      'budget',   'min'),
#             (      'budget',   '25%'),
#             (      'budget',   '50%'),
#             (      'budget',   '75%'),
#             (      'budget',   'max'),
#             (          'id', 'count'),
#             (          'id',  'mean'),
#             (          'id',   'std'),
#             (          'id',   'min'),
#             (          'id',   '25%'),
#             (          'id',   '50%'),
#             (          'id',   '75%'),
#             (          'id',   'max'),
#             (  'popularity', 'count'),
#             (  'popularity',  'mean'),
#             (  'popularity',   'std'),
#             (  'popularity',   'min'),
#             (  'popularity',   '25%'),
#             (  'popularity',   '50%'),
#             (  'popularity',   '75%'),
#             (  'popularity',   'max'),
# ...

# %%
df.groupby('original_language').describe()['runtime']['25%']
# Out:
# original_language
# af     94.00
# ar     90.00
# cn     97.25
# cs     96.75
# da    110.00
# de     90.00
# el     94.00
# en     93.00
# es     99.75
# fa     89.75
# fr     95.00
# he    102.00
# hi    120.50
# hu    140.00
# id    104.50
# is     85.00
# it     90.00
# ja    110.00
# ko    117.00
# ky    135.00
# nb    103.00
# nl    103.00
# no     91.00
# pl     80.00
# ps     83.00
# pt    106.00
# ro    106.25
# ru     95.00
# sl     83.00
# sv    109.00
# ta    158.75
# te    159.00
# th    103.00
# tr    122.00
# vi    135.00
# xx    100.00
# zh    102.00
# Name: 25%, dtype: float64

# %%
df.groupby('original_language').describe()['runtime']['25%'].iloc[2]
# Out:
# 97.25

# %%
df.groupby('original_language').describe()['runtime']['25%'].columns
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-67-701bef76baba> in <module>
# ----> 1 df.groupby('original_language').describe()['runtime']['25%'].columns
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
df.groupby('original_language').describe()['runtime']['25%'].values
# Out:
# array([ 94.  ,  90.  ,  97.25,  96.75, 110.  ,  90.  ,  94.  ,  93.  ,
#         99.75,  89.75,  95.  , 102.  , 120.5 , 140.  , 104.5 ,  85.  ,
#         90.  , 110.  , 117.  , 135.  , 103.  , 103.  ,  91.  ,  80.  ,
#         83.  , 106.  , 106.25,  95.  ,  83.  , 109.  , 158.75, 159.  ,
#        103.  , 122.  , 135.  , 100.  , 102.  ])

# %%
df.groupby('original_language').describe()['runtime']['25%'].index
# Out:
# Index(['af', 'ar', 'cn', 'cs', 'da', 'de', 'el', 'en', 'es', 'fa', 'fr', 'he',
#        'hi', 'hu', 'id', 'is', 'it', 'ja', 'ko', 'ky', 'nb', 'nl', 'no', 'pl',
#        'ps', 'pt', 'ro', 'ru', 'sl', 'sv', 'ta', 'te', 'th', 'tr', 'vi', 'xx',
#        'zh'],
#       dtype='object', name='original_language')

# %%
df.groupby('original_language').describe()['runtime']['25%']['af']
# Out:
# 94.0

# %%
df.groupby('original_language')['revenue'].max()
# Out:
# original_language
# af       9879971
# ar             0
# cn     156844753
# cs             0
# da     170000000
# de      92180910
# el        110197
# en    2787965087
# es      99067206
# fa        900000
# fr     173921954
# he      11125849
# hi      46000000
# hu             0
# id       4105187
# is            11
# it      14500000
# ja     274925095
# ko      88489643
# ky             0
# nb       4159678
# nl      26193068
# no       1984662
# pl      10700000
# ps             0
# pt      30641770
# ro       1185783
# ru      32000000
# sl             0
# sv             0
# ta             0
# te     100000000
# th      27165581
# tr             0
# vi        639000
# xx      55260558
# zh     213525736
# Name: revenue, dtype: int64

# %%
df.groupby('original_language')['revenue'].max()['ja']
# Out:
# 274925095

# %%
df.groupby('original_language')['revenue'].idxmax()
# Out:
# original_language
# af    3936
# ar    4164
# cn    1357
# cs    2906
# da    4586
# de    2724
# el    4605
# en       0
# es    3562
# fa    4695
# fr    1260
# he    4104
# hi    3228
# hu    2894
# id    4326
# is    3131
# it    4672
# ja    2294
# ko    2877
# ky    4275
# nb    3845
# nl    2052
# no    4464
# pl    3999
# ps    4523
# pt    3866
# ro    4434
# ru    3733
# sl    4510
# sv    2474
# ta    2271
# te    1290
# th    3518
# tr    3231
# vi    4272
# xx    2787
# zh    2515
# Name: revenue, dtype: int64

# %%
df.iloc[df.groupby('original_language')['revenue'].idxmax()]
# Out:
#          budget                                             genres  \
# 3936    3000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 4164          0  [{"id": 99, "name": "Documentary"}, {"id": 18,...
# 1357   36000000  [{"id": 28, "name": "Action"}, {"id": 18, "nam...
# 2906          0  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 4586   35000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 2724   18339750  [{"id": 18, "name": "Drama"}, {"id": 36, "name...
# 4605          0                      [{"id": 18, "name": "Drama"}]
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3562    5500000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4695     180000  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 1260   10000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4104    2000000  [{"id": 18, "name": "Drama"}, {"id": 16, "name...
# 3228    7700000                 [{"id": 10749, "name": "Romance"}]
# ...

# %%
df[(df.iloc[df.groupby('original_language')['revenue'].idxmax()]) && (df['original_language'] == 'ja')]
# Out:
#          budget                                             genres  \
# 3936    3000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 4164          0  [{"id": 99, "name": "Documentary"}, {"id": 18,...
# 1357   36000000  [{"id": 28, "name": "Action"}, {"id": 18, "nam...
# 2906          0  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 4586   35000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 2724   18339750  [{"id": 18, "name": "Drama"}, {"id": 36, "name...
# 4605          0                      [{"id": 18, "name": "Drama"}]
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3562    5500000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4695     180000  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 1260   10000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4104    2000000  [{"id": 18, "name": "Drama"}, {"id": 16, "name...
# 3228    7700000                 [{"id": 10749, "name": "Romance"}]
# ...

# %%
df.iloc[df.groupby('original_language')['revenue'].idxmax()].columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df2 = df.iloc[df.groupby('original_language')['revenue'].idxmax()]

# %%
df2[df2['original_language'] == 'ja']
# Out:
#         budget                                             genres  \
# 2294  15000000  [{"id": 14, "name": "Fantasy"}, {"id": 12, "na...
#
#                                     homepage   id  \
# 2294  http://movies.disney.com/spirited-away  129
#
#                                                keywords original_language  \
# 2294  [{"id": 616, "name": "witch"}, {"id": 970, "na...                ja
#
#      original_title                                           overview  \
# 2294       千と千尋の神隠し  A ten year old girl who wanders away from her ...
#
#       popularity                      production_companies  \
# 2294  118.968562  [{"name": "Studio Ghibli", "id": 10342}]
#
#                          production_countries release_date    revenue  \
# 2294  [{"iso_3166_1": "JP", "name": "Japan"}]   2001-07-20  274925095
#
#       runtime                                   spoken_languages    status  \
# 2294    125.0  [{"iso_639_1": "ja", "name": "\u65e5\u672c\u8a...  Released
#
# ...

# %%
df3 = df[df['original_language'] == 'ja']

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 97 to 4792
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                16 non-null     int64
#  1   genres                16 non-null     object
#  2   homepage              5 non-null      object
#  3   id                    16 non-null     int64
#  4   keywords              16 non-null     object
#  5   original_language     16 non-null     object
#  6   original_title        16 non-null     object
#  7   overview              16 non-null     object
#  8   popularity            16 non-null     float64
#  9   production_companies  16 non-null     object
#  10  production_countries  16 non-null     object
#  11  release_date          16 non-null     object
#  12  revenue               16 non-null     int64
#  13  runtime               16 non-null     float64
#  14  spoken_languages      16 non-null     object
# ...

# %%
df3[df3['revenue'] == df3.max()['revenue']]
# Out:
#         budget                                             genres  \
# 2294  15000000  [{"id": 14, "name": "Fantasy"}, {"id": 12, "na...
#
#                                     homepage   id  \
# 2294  http://movies.disney.com/spirited-away  129
#
#                                                keywords original_language  \
# 2294  [{"id": 616, "name": "witch"}, {"id": 970, "na...                ja
#
#      original_title                                           overview  \
# 2294       千と千尋の神隠し  A ten year old girl who wanders away from her ...
#
#       popularity                      production_companies  \
# 2294  118.968562  [{"name": "Studio Ghibli", "id": 10342}]
#
#                          production_countries release_date    revenue  \
# 2294  [{"iso_3166_1": "JP", "name": "Japan"}]   2001-07-20  274925095
#
#       runtime                                   spoken_languages    status  \
# 2294    125.0  [{"iso_639_1": "ja", "name": "\u65e5\u672c\u8a...  Released
#
# ...
