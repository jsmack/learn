# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
df1 = pd.read_csv('train.csv')
df1 = df1.dropna(subset=['Age'])
sns.distplot(df1['Age'])

# %%
df1.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
sns.set()
sns.distplot(df1['Age'],bins=50)

# %%
sns.jointplot(x='Age', y='Fare',data=df1,kind='hex')

# %%
sns.jointplot(x='Age', y='Fare', data=df1,alpha=0.5)

# %%
sns.pairplot(df1)

# %%
sns.pairplot(df1, hue='Survived', kind='scatter', plot_kws={'alpha': 0.5})
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
